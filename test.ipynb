# %%
import pandas as pd

# %%
energy_use2019 = pd.read_csv("energy_distribution_data_CY2019.csv")
energy_use2019
# Out:
#      BUILDING_NUMBER                     BUILDING_NAME_LONG  \
# 0                  1  Henry L Pierce Engineering Laboratory
# 1                  1  Henry L Pierce Engineering Laboratory
# 2                  1  Henry L Pierce Engineering Laboratory
# 3                  1  Henry L Pierce Engineering Laboratory
# 4                  1  Henry L Pierce Engineering Laboratory
# ...              ...                                    ...
# 4210            WW15                          Building WW15
# 4211            WW15                          Building WW15
# 4212            WW15                          Building WW15
# 4213            WW15                          Building WW15
# 4214            WW15                          Building WW15
#
#      BUILDING_GROUP_LEVEL1       CLUSTER_NUM BUILDING_TYPE BUILDING_USE SITE  \
# 0                  Non-CUP   Lab & Mixed Use      ACADEMIC          AER  MIT
# 1                  Non-CUP   Lab & Mixed Use      ACADEMIC          AER  MIT
# ...

# %%
energy_use2019.columns
# Out:
# Index(['BUILDING_NUMBER', 'BUILDING_NAME_LONG', 'BUILDING_GROUP_LEVEL1',
#        'CLUSTER_NUM', 'BUILDING_TYPE', 'BUILDING_USE', 'SITE', 'CAMPUS_SECTOR',
#        'YEAR_CONST_BEGAN', 'YEAR_OCCUPIED', 'LATITUDE_WGS', 'LONGITUDE_WGS',
#        'OWNERSHIP_TYPE', 'BUILDING_HEIGHT', 'NUM_OF_ROOMS', 'EXT_GROSS_AREA',
#        'ASSIGNABLE_AREA', 'NON_ASSIGNABLE_AREA', 'BLDG_SRV', 'CIRCULAT',
#        'CLASSRMS', 'GENERAL', 'HEALTH', 'LABS', 'MECHANIC', 'OFFICES',
#        'RESIDENT', 'SPECIAL', 'STUDY', 'SUPPORT', 'UNCLASS', 'USEABLE_AREA',
#        'STRUCT_AREA', 'LEVEL3_CATEGORY', 'LEVEL2_CATEGORY', 'NUMBER_OF_UNITS',
#        'UNIT_OF_MEASURE', 'MMBTU', 'kBTU', 'GHG', 'PI_CONNECTION',
#        'METER_STATUS', 'START_DATE', 'END_DATE', 'START_DATE_USE'],
#       dtype='object')

# %%
energy_use2019.groupby("LEVEL3_CATEGORY")
# Out:
#                  YEAR_CONST_BEGAN  YEAR_OCCUPIED  LATITUDE_WGS  LONGITUDE_WGS  \
# LEVEL3_CATEGORY
# Chilled Water         1951.010574    1961.183976     42.360228     -71.091387
# Electricity           1948.503597    1963.539792     42.362157     -71.097292
# Fuel Oil #2           1936.000000    1937.000000     42.358517     -71.087730
# Gas                   1949.723338    1967.968703     42.359592     -71.094451
# Steam                 1949.787485    1959.503505     42.359761     -71.092008
#
#                  BUILDING_HEIGHT  NUM_OF_ROOMS  EXT_GROSS_AREA  \
# LEVEL3_CATEGORY
# Chilled Water          79.079586    393.419481   126301.803335
# Electricity            66.946308    306.306924   103637.312217
# Fuel Oil #2            21.300000    139.909091    99460.800909
# Gas                    65.989702    344.696576   112412.583658
# Steam                  80.621262    378.265060   120659.867307
#
#                  ASSIGNABLE_AREA  NON_ASSIGNABLE_AREA     BLDG_SRV  ...  \
# ...
