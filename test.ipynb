# %%
import pandas as pd

# %%
energy_use2020 = pd.read_csv("energy_distribution_data_CY2020.csv")
energy_use2020
# Out:
#      BUILDING_NUMBER                     BUILDING_NAME_LONG  \
# 0                  1  Henry L Pierce Engineering Laboratory
# 1                  1  Henry L Pierce Engineering Laboratory
# 2                  1  Henry L Pierce Engineering Laboratory
# 3                  1  Henry L Pierce Engineering Laboratory
# 4                  1  Henry L Pierce Engineering Laboratory
# ...              ...                                    ...
# 4133            WW15                          Building WW15
# 4134            WW15                          Building WW15
# 4135            WW15                          Building WW15
# 4136            WW15                          Building WW15
# 4137            WW15                          Building WW15
#
#      BUILDING_GROUP_LEVEL1       CLUSTER_NUM BUILDING_TYPE BUILDING_USE SITE  \
# 0                  Non-CUP   Lab & Mixed Use      ACADEMIC          AER  MIT
# 1                  Non-CUP   Lab & Mixed Use      ACADEMIC          AER  MIT
# ...

# %%
energy_use2020.groupby("BUILDING_NUMBER").mean()
# Out:
#                  YEAR_CONST_BEGAN  YEAR_OCCUPIED  LATITUDE_WGS  LONGITUDE_WGS  \
# BUILDING_NUMBER
# 1                          1913.0         1917.0     42.358086     -71.092357
# 10                         1913.0         1916.0     42.359677     -71.092016
# 11                         1927.0         1928.0     42.359522     -71.092773
# 12                            NaN            NaN           NaN            NaN
# 13                         1963.0         1965.0     42.359944     -71.092552
# ...                           ...            ...           ...            ...
# W91                        1947.0         1949.0     42.354324     -71.104426
# W92                           NaN         1999.0     42.354920     -71.104617
# W97                           NaN            NaN           NaN            NaN
# W98                           NaN            NaN     42.353955     -71.106645
# WW15                       1969.0            NaN     42.355361     -71.109470
#
# ...
